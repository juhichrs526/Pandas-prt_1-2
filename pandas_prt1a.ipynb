# %%
#import pandas lib
import pandas as pd

# %%
#how to make data
#importing the data
x={
    'Name':['xyz','pqr','abc'],
    'Age':['21','22','23'],
    'marks':['26','36','42']
}

# %%
x
# Out:
# {'Name': ['xyz', 'pqr', 'abc'],
#  'Age': ['21', '22', '23'],
#  'marks': ['26', '36', '42']}

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#   Name Age marks
# 0  xyz  21    26
# 1  pqr  22    36
# 2  abc  23    42

# %%
df['Name']
# Out:
# 0    xyz
# 1    pqr
# 2    abc
# Name: Name, dtype: object

# %%
df['Name'][0]
# Out:
# 'xyz'

# %%
df['Age'][0]
# Out:
# '21'

# %%
import pandas as pd

# %%
x={
    'Name':['a','b','c'],
    'age':['25','36','42'],
    'salary':['2500','3600','3400']
}

# %%
x
# Out:
# {'Name': ['a', 'b', 'c'],
#  'age': ['25', '36', '42'],
#  'salary': ['2500', '3600', '3400']}

# %%
df=pd.DataFrame(x)

# %%
df
# Out:
#   Name age salary
# 0    a  25   2500
# 1    b  36   3600
# 2    c  42   3400

# %%
df['Name']
# Out:
# 0    a
# 1    b
# 2    c
# Name: Name, dtype: object

# %%
df['age'][1]
# Out:
# '36'

# %%
df['Name'][1]=123

# %%
df
# Out:
#   Name age salary
# 0    a  25   2500
# 1  123  36   3600
# 2    c  42   3400

# %%
df['salary'][1]=36

# %%
df
# Out:
#   Name age salary
# 0    a  25   2500
# 1  123  36     36
# 2    c  42   3400

# %%
#storing the data
#.csv----> commma seperated value
#.xlsx--->excel
file=df.to_csv('myfile.csv')

# %%
file

# %%
#read the file
read_file=pd.read_csv(r'C:\Users\DeLL\Desktop\python project\myfile.csv')

# %%
read_file
# Out:
#    Unnamed: 0 Name  age  salary
# 0           0    a   25    2500
# 1           1  123   36      36
# 2           2    c   42    3400

# %%
df=pd.read_csv(r'C:\Users\DeLL\Downloads\25_Complaints_against_police.csv')

# %%
df
# Out:
#                      Area_Name  Year                            Sub_group  \
# 0    Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1               Andhra Pradesh  2001  Complaints Against Police Personnel
# 2            Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                        Assam  2001  Complaints Against Police Personnel
# 4                        Bihar  2001  Complaints Against Police Personnel
# ..                         ...   ...                                  ...
# 345                 Tamil Nadu  2010  Complaints Against Police Personnel
# 346                    Tripura  2010  Complaints Against Police Personnel
# 347              Uttar Pradesh  2010  Complaints Against Police Personnel
# 348                Uttarakhand  2010  Complaints Against Police Personnel
# 349                West Bengal  2010  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# ...

# %%
df1=pd.read_excel(r'C:\Users\DeLL\Downloads\EntriesGender.xlsx')

# %%
df1
# Out:
#                Discipline  Female  Male  Total
# 0          3x3 Basketball      32    32     64
# 1                 Archery      64    64    128
# 2     Artistic Gymnastics      98    98    196
# 3       Artistic Swimming     105     0    105
# 4               Athletics     969  1072   2041
# 5               Badminton      86    87    173
# 6       Baseball/Softball      90   144    234
# 7              Basketball     144   144    288
# 8        Beach Volleyball      48    48     96
# 9                  Boxing     102   187    289
# 10           Canoe Slalom      41    41     82
# 11           Canoe Sprint     123   126    249
# 12  Cycling BMX Freestyle      10     9     19
# 13     Cycling BMX Racing      24    24     48
# 14  Cycling Mountain Bike      38    38     76
# 15           Cycling Road      70   131    201
# 16          Cycling Track      90    99    189
# 17                 Diving      72    71    143
# 18             Equestrian      73   125    198
# ...

# %% [markdown]
# # pandas_part2b

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\DeLL\Downloads\25_Complaints_against_police.csv')

# %%
df
# Out:
#                      Area_Name  Year                            Sub_group  \
# 0    Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1               Andhra Pradesh  2001  Complaints Against Police Personnel
# 2            Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                        Assam  2001  Complaints Against Police Personnel
# 4                        Bihar  2001  Complaints Against Police Personnel
# ..                         ...   ...                                  ...
# 345                 Tamil Nadu  2010  Complaints Against Police Personnel
# 346                    Tripura  2010  Complaints Against Police Personnel
# 347              Uttar Pradesh  2010  Complaints Against Police Personnel
# 348                Uttarakhand  2010  Complaints Against Police Personnel
# 349                West Bengal  2010  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# ...

# %%
df.head()
# Out:
#                    Area_Name  Year                            Sub_group  \
# 0  Andaman & Nicobar Islands  2001  Complaints Against Police Personnel
# 1             Andhra Pradesh  2001  Complaints Against Police Personnel
# 2          Arunachal Pradesh  2001  Complaints Against Police Personnel
# 3                      Assam  2001  Complaints Against Police Personnel
# 4                      Bihar  2001  Complaints Against Police Personnel
#
#    CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 0                      10                                      4
# 1                    3078                                     72
# 2                      24                                     39
# 3                      17                                      3
# 4                       1                                      1
#
#    CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# 0                                                  0
# ...

# %%
df.tail()
# Out:
#          Area_Name  Year                            Sub_group  \
# 345     Tamil Nadu  2010  Complaints Against Police Personnel
# 346        Tripura  2010  Complaints Against Police Personnel
# 347  Uttar Pradesh  2010  Complaints Against Police Personnel
# 348    Uttarakhand  2010  Complaints Against Police Personnel
# 349    West Bengal  2010  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 345                     107                                     67
# 346                      28                                      7
# 347                    8701                                   8326
# 348                      15                                     71
# 349                       5                                     27
#
#      CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# 345                                                 15
# 346                                                  5
# ...

# %%
df.tail(11)
# Out:
#          Area_Name  Year                            Sub_group  \
# 339       Nagaland  2010  Complaints Against Police Personnel
# 340         Odisha  2010  Complaints Against Police Personnel
# 341     Puducherry  2010  Complaints Against Police Personnel
# 342         Punjab  2010  Complaints Against Police Personnel
# 343      Rajasthan  2010  Complaints Against Police Personnel
# 344         Sikkim  2010  Complaints Against Police Personnel
# 345     Tamil Nadu  2010  Complaints Against Police Personnel
# 346        Tripura  2010  Complaints Against Police Personnel
# 347  Uttar Pradesh  2010  Complaints Against Police Personnel
# 348    Uttarakhand  2010  Complaints Against Police Personnel
# 349    West Bengal  2010  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 339                       7                                      0
# 340                      30                                      7
# ...

# %%
df.sample()
# Out:
#     Area_Name  Year                            Sub_group  \
# 129  Nagaland  2004  Complaints Against Police Personnel
#
#      CPA_-_Cases_Registered  CPA_-_Cases_Reported_for_Dept._Action  \
# 129                      10                                      3
#
#      CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# 129                                                  0
#
#      CPA_-_Complaints_Received/Alleged  CPA_-_No_of_Departmental_Enquiries  \
# 129                                 11                                   1
#
#      CPA_-_No_of_Magisterial_Enquiries  \
# 129                                  0
#
#      CPA-_Cases_Sent_for_Trials/Charge-sheeted  ...  \
# 129                                          6  ...
#
#      CPB_-_Police_Personnel_Convicted  \
# 129                                 1
#
#      CPB_-_Police_Personnel_sent_up_for_Trial  \
# 129                                         8
#
#      CPB_-_Police_Personnel_Trial_Completed  \
# ...

# %%
df.describe()
# Out:
#               Year  CPA_-_Cases_Registered  \
# count   350.000000              350.000000
# mean   2005.500000              257.465714
# std       2.876393              963.522756
# min    2001.000000                0.000000
# 25%    2003.000000                3.000000
# 50%    2005.500000               17.500000
# 75%    2008.000000               98.750000
# max    2010.000000             8701.000000
#
#        CPA_-_Cases_Reported_for_Dept._Action  \
# count                             350.000000
# mean                              161.368571
# std                               682.832843
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 6.000000
# 75%                                64.000000
# max                              8326.000000
#
#        CPA_-_Complaints/Cases_Declared_False/Unsubstantiated  \
# count                                         350.000000
# ...

# %%
df.isnull()
# Out:
#      Area_Name   Year  Sub_group  CPA_-_Cases_Registered  \
# 0        False  False      False                   False
# 1        False  False      False                   False
# 2        False  False      False                   False
# 3        False  False      False                   False
# 4        False  False      False                   False
# ..         ...    ...        ...                     ...
# 345      False  False      False                   False
# 346      False  False      False                   False
# 347      False  False      False                   False
# 348      False  False      False                   False
# 349      False  False      False                   False
#
#      CPA_-_Cases_Reported_for_Dept._Action  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ...

# %%
df.isnull().sum()
# Out:
# Area_Name                                                          0
# Year                                                               0
# Sub_group                                                          0
# CPA_-_Cases_Registered                                             0
# CPA_-_Cases_Reported_for_Dept._Action                              0
# CPA_-_Complaints/Cases_Declared_False/Unsubstantiated              0
# CPA_-_Complaints_Received/Alleged                                  0
# CPA_-_No_of_Departmental_Enquiries                                 0
# CPA_-_No_of_Magisterial_Enquiries                                  0
# CPA-_Cases_Sent_for_Trials/Charge-sheeted                          0
# CPA-_No_of_Judicial_Enquiries                                      0
# CPB_-_Police_Personnel_Acquitted                                   0
# CPB_-_Police_Personnel_Convicted                                   0
# CPB_-_Police_Personnel_sent_up_for_Trial                           0
# ...

# %%
#not null
df.notnull()
# Out:
#      Area_Name  Year  Sub_group  CPA_-_Cases_Registered  \
# 0         True  True       True                    True
# 1         True  True       True                    True
# 2         True  True       True                    True
# 3         True  True       True                    True
# 4         True  True       True                    True
# ..         ...   ...        ...                     ...
# 345       True  True       True                    True
# 346       True  True       True                    True
# 347       True  True       True                    True
# 348       True  True       True                    True
# 349       True  True       True                    True
#
#      CPA_-_Cases_Reported_for_Dept._Action  \
# 0                                     True
# 1                                     True
# 2                                     True
# 3                                     True
# 4                                     True
# ...

# %%
df.notnull().sum()
# Out:
# Area_Name                                                          350
# Year                                                               350
# Sub_group                                                          350
# CPA_-_Cases_Registered                                             350
# CPA_-_Cases_Reported_for_Dept._Action                              350
# CPA_-_Complaints/Cases_Declared_False/Unsubstantiated              350
# CPA_-_Complaints_Received/Alleged                                  350
# CPA_-_No_of_Departmental_Enquiries                                 350
# CPA_-_No_of_Magisterial_Enquiries                                  350
# CPA-_Cases_Sent_for_Trials/Charge-sheeted                          350
# CPA-_No_of_Judicial_Enquiries                                      350
# CPB_-_Police_Personnel_Acquitted                                   350
# CPB_-_Police_Personnel_Convicted                                   350
# ...

# %%
df1=pd.read_csv(r'C:\Users\DeLL\Downloads\US-Cities-Population2.csv')

# %%
df1
# Out:
#      2015 rank           City         State  2015 estimate  2010 Census  \
# 0            1  not available      New York        8550405    8175133.0
# 1            2    Los Angeles    California        3971883    3792621.0
# 2            3        Chicago      Illinois  not available    2695598.0
# 3            4        Houston         Texas        2296224    2100263.0
# 4            5   Philadelphia  Pennsylvania        1567442    1526006.0
# ..         ...            ...           ...            ...          ...
# 299        300        Greeley      Colorado         100883      92889.0
# 300        301          Davie       Florida         100882      91992.0
# 301        302     San Angelo         Texas         100450      93200.0
# 302        303  Jurupa Valley    California         100314          0.0
# 303        304         Renton    Washington         100242      90927.0
#
#      Change 2014 land area 2010 population density              Location
# ...

# %%
df1.isnull().sum()
# Out:
# 2015 rank                  0
# City                       0
# State                      0
# 2015 estimate              0
# 2010 Census                1
# Change                     1
# 2014 land area             0
# 2010 population density    1
# Location                   0
# dtype: int64

# %%
df1.notnull().sum()
# Out:
# 2015 rank                  304
# City                       304
# State                      304
# 2015 estimate              304
# 2010 Census                303
# Change                     303
# 2014 land area             304
# 2010 population density    303
# Location                   304
# dtype: int64

# %%
df1['City'].isnull().sum()
# Out:
# 0

# %%
import seaborn as sns

# %%
sns.heatmap(df1.isnull())
# Out:
# <AxesSubplot:>

# %%
df1
# Out:
#      2015 rank           City         State  2015 estimate  2010 Census  \
# 0            1  not available      New York        8550405    8175133.0
# 1            2    Los Angeles    California        3971883    3792621.0
# 2            3        Chicago      Illinois  not available    2695598.0
# 3            4        Houston         Texas        2296224    2100263.0
# 4            5   Philadelphia  Pennsylvania        1567442    1526006.0
# ..         ...            ...           ...            ...          ...
# 299        300        Greeley      Colorado         100883      92889.0
# 300        301          Davie       Florida         100882      91992.0
# 301        302     San Angelo         Texas         100450      93200.0
# 302        303  Jurupa Valley    California         100314          0.0
# 303        304         Renton    Washington         100242      90927.0
#
#      Change 2014 land area 2010 population density              Location
# ...

# %%
df1.shape
# Out:
# (304, 9)
